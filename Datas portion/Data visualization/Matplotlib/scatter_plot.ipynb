# %%
import matplotlib.pyplot as plt

# %%
#scatter plots
people = ["Person A", "Person B", "Person C", "Person D", "Person E", 
          "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
bp = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

colors = ["green" if x<135 else "red" for x in bp]

plt.scatter(age,bp,cmap = "OrRd",c = bp,s = bp,alpha = 0.9,)
plt.title("correlation of age and bp")
plt.xlabel("age")
plt.ylabel("blood pressure")
plt.grid()
plt.colorbar(label = "bp")

for i in range(len(people)):
    plt.annotate(people[i],xy = (age[i],bp[i]) , xytext = (age[i]+2,bp[i] + 2)) #xytext is default
plt.xlim(min(age),max(age)+10)
plt.ylim(min(bp),max(bp)+5)
# Out:
# (110.0, 155.0)

# %%
#multiple dataset in scatter plots
cities = ["City A", "City B", "City C", "City D", "City E"]

# Winter: Temperature (°C) vs Humidity (%)
winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]

# Summer: Temperature (°C) vs Humidity (%)
summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

plt.scatter(winter_temp,winter_humidity,label = "for winter")
plt.scatter(summer_temp,summer_humidity,label = "for summer")
plt.title("winter vs summer")
plt.xlabel("temperature")
plt.ylabel("humidity")
plt.legend()
