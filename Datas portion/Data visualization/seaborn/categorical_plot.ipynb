# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
#barplot
sns.barplot(
    data = tips,
    x = "day",
    y = "tip",
    hue = "sex"
)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#boxplot
sns.boxplot(
    data = tips,
    x = "days",
    y = "tips"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 #boxplot
# ----> 2 sns.boxplot(
#       3     data = tips,
#       4     x = "days",
#       5     y = "tips"
#       6 )
#
# File ~\AppData\Local\anaconda3\envs\datas_env\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)   1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
# ...
