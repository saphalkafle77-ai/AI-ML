# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#comparing of two data set
#oscar winner movies

oscar_movies = [
    "The dark knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Agro"
]

oscar_revenue = [1005,170,437,133,232]#in$M

non_oscar_movies = ["slumdog Millionare","Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue = [378,2788,829,186,275] #in $M\

years = [2008,2009,2010,2011,2012]
x = np.arange(len(years))
width = 0.4

plt.bar(x-width/2,oscar_revenue,width,label="oscar winners")
plt.bar(x+width/2,non_oscar_revenue,width,label= "non oscar winners")
plt.title("oscar vs non-oscar movies revenue")
plt.xlabel("years")
plt.ylabel("revenue")
plt.legend()
plt.xticks(x,years)
# Out:
# ([<matplotlib.axis.XTick at 0x1725fdb20d0>,
#   <matplotlib.axis.XTick at 0x1725fe11590>,
#   <matplotlib.axis.XTick at 0x1725fe11950>,
#   <matplotlib.axis.XTick at 0x1725fe11d10>,
#   <matplotlib.axis.XTick at 0x1725fe120d0>],
#  [Text(0, 0, '2008'),
#   Text(1, 0, '2009'),
#   Text(2, 0, '2010'),
#   Text(3, 0, '2011'),
#   Text(4, 0, '2012')])

# %%
#Horizontal bar chart
oscar_movies = [
    "The dark knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Agro"
]
years = [2008,2009,2010,2011,2012]
oscar_revenue = [1005,170,437,133,232]#in$M

plt.barh(oscar_movies,oscar_revenue)
plt.title("oscar movie revenue")
plt.xlabel("revenue")
plt.ylabel("years")
# Out:
# Text(0, 0.5, 'years')
