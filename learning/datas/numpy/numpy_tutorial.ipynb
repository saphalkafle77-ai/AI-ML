# %%
import numpy as np
import time

# %%
# arr = np.array([2,3,5,7])
# print(arr,type(arr))

# %%
size = 10_000_000
#python list
py_list = list(range(size))
start = time.time()
s1_list = [x**2 for x in py_list]
end = time.time()
print(f"python list time is {end-start}second")

#numpy
np_arr = np.array(py_list)
start = time.time()
sq_array = np_arr **2
end = time.time()
print(f"numpy array time is {end-start}second")
# Out:
# python list time is 4.7408154010772705second
# numpy array time is 0.030141592025756836second

# %%
import sys
print(f"python list size is {sys.getsizeof(py_list) * len(py_list)}")
print(f"numpy array size is {np_arr.nbytes}")
# Out:
# python list size is 800000560000000
# numpy array size is 80000000
