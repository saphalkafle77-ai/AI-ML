# %%
import pandas as pd

# %%
info = {
    "Name": ["Rahul","harshita","saphal"],
    "cgpa": [9.5,7.5,8.6]
}
df = pd.DataFrame(info)
print(df)
# Out:
#        Name  cgpa
# 0     Rahul   9.5
# 1  harshita   7.5
# 2    saphal   8.6

# %%
df
# Out:
#        Name  cgpa
# 0     Rahul   9.5
# 1  harshita   7.5
# 2    saphal   8.6
