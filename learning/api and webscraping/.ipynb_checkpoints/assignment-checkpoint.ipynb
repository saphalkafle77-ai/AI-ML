# %%
import requests

# %%
dog = "https://dog.ceo/api/breeds/image/random"
request = requests.get(dog)

# %%
json_data = request.json()

# %%
request
# Out:
# <Response [503]>

# %%
df = pd.json_normalize(json_data["data"])

# %%
df
