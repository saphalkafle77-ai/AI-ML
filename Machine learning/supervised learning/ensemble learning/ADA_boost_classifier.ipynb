# %%
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
#making a simple dataset for classification
X,y = make_classification(
    n_samples = 600,
    n_features = 20,
    n_informative = 10,
    n_redundant  = 2,
    random_state = 42
)
#train test split
X_train,X_test,y_train,y_test = train_test_split(
    X,y,test_size = 0.3,random_state = 42
)
#create base model 
base_model = DecisionTreeClassifier(
    max_depth = 1
)
#Implementing adaptive boosting classifier
adac = AdaBoostClassifier(
    estimator = base_model,
    n_estimators = 100,
    
    random_state = 42
)
adac.fit(X_train,y_train)
y_pred = adac.predict(X_test)
print("accuracy",accuracy_score(y_test,y_pred))
# Out:
# accuracy 0.9111111111111111

# %%
#for regression dataset
X,y = make_regression(
    n_samples = 1000,
    n_features = 20,
    noise = 10,
    random_state = 42
)
#train test split
X_train,X_test,y_train,y_test = train_test_split(
    X,y,test_size = 0.3,random_state = 42
)
#create base model
base_model = DecisionTreeRegressor(
    max_depth = 3,
)
adar = AdaBoostRegressor(
    estimator = base_model,
    n_estimators = 100,
    random_state = 42
)
adar.fit(X_train,y_train)
y_pred = adar.predict(X_test)
#evaluation metrics
print("r2_score",r2_score(y_test,y_pred))
# Out:
# r2_score 0.7701369148881556
