# %%
# !pip install langchain langchain-core langchain-community pypdf pymupdf sentence-transformers chromadb

# %%
from langchain_core.documents import Document

# %%
# sample_doc = Document(
#     page_content = "Hello World",
#     metadata = {"source": "https://www.google.com"}
# )

# %% [markdown]
# ### Converting Text Data into Documents

# %%
# from langchain_community.document_loaders.text import TextLoader

# txt_loader = TextLoader("data/Python.txt",encoding="utf-8")
# document = loader.load()

# %% [markdown]
# ### Convert pdf into documents

# %%
# from langchain_community.document_loaders.pdf import PyPDFLoader #for simple pdf

# pdf_loader = PyPDFLoader("data/attention_is_all_you_need.pdf")
# p_document = pdf_loader.load()

# %%
# from langchain_community.document_loaders.pdf import PyMuPDFLoader #for complex pdf

# pdf_loader = PyMuPDFLoader("data/pdf/attention_is_all_you_need.pdf")
# p_document = pdf_loader.load()

# %%
#
